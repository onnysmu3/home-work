# %%
canid = open("/home/eeb177-student/Desktop/eeb-177/class-assignments/CA_Thurs_030217/test.csv")

# %%
canid.readline()
canid_dict = {}
for line in canid:
    species = line.split(",")[5]
    min_size = line.split(",")[11]
    max_size = line.split(",")[10]
    occ = line.split(",")[0]
    values = [species, min_size, max_size]
    canid_dict[occ] = values

# %%
print(canid_dict)
# Out:
# {'"1217259"': ['"Leptocyon leidyi"', '"15.97"', '"20.43"'], '"185259"': ['"Paratomarctus temerarius"', '"13.6"', '"15.97"'], '"183119"': ['"Desmocyon thomsoni"', '"20.43"', '"24.8"'], '"199271"': ['"Canis dirus"', '"0.0117"', '"0.126"'], '"197572"': ['"Canis edwardii"', '"0.3"', '"1.8"'], '"190725"': ['"Paratomarctus temerarius"', '"13.6"', '"15.97"'], '"192134"': ['"Borophagus secundus"', '"4.9"', '"10.3"'], '"1118503"': ['"Canis proplatensis"', '"0.781"', '"2.588"'], '"187326"': ['"Epicyon haydeni"', '"10.3"', '"13.6"'], '"180707"': ['"Hesperocyon gregarius"', '"30.8"', '"33.3"'], '"183379"': ['"Desmocyon thomsoni"', '"15.97"', '"20.43"'], '"191639"': ['"Borophagus"', '"4.9"', '"10.3"'], '"339251"': ['"Canis"', '"2.588"', '"5.333"'], '"1217284"': ['"Leptocyon vafer"', '"10.3"', '"13.6"'], '"181099"': ['"Hesperocyon gregarius"', '"30.8"', '"33.3"'], '"1217308"': ['"Leptocyon matthewi"', '"10.3"', '"13.6"'], '"181590"': ['"Archaeocyon pavidus"', '"20.43"', '"30.8"'], '"185132"': ['"A
# ...

# %%
canid = open("/home/eeb177-student/Desktop/eeb-177/class-assignments/CA_Thurs_030217/test.csv")
canid.readline()
canid_dict = {}
#use defaultdict
from collections import defaultdict
species_ranges = defaultdict(list)

for line in canid:
    species = line.split('","')[5]
    min_age = line.split('","')[11]
    max_age = line.split('","')[10]
    mean_age = (float(min_age) + float(max_age) / 2)
    species_ranges[species].append(mean_age)

# %%
species_ranges.values()
# Out:
# dict_values([[21.805, 26.19], [17.1, 17.1, 17.1, 17.1, 17.1, 17.1, 17.1, 17.1, 17.1, 16.848, 16.848, 17.1], [17.1, 21.585, 17.1, 17.1, 17.1, 17.1, 17.1, 16.848, 21.585], [37.95, 10.05, 16.848, 17.1, 17.1, 17.1, 17.1, 10.05, 21.585, 10.05, 17.1, 17.1, 17.1, 10.05, 17.1, 16.848, 10.05, 17.1, 17.1, 17.1, 17.1, 17.1, 17.1, 17.1, 17.1, 4.388, 0.0747, 0.0747, 1.3057], [4.25], [17.1], [32.83, 32.83, 21.585, 18.285, 21.585, 17.1, 17.1, 16.848, 21.585, 17.1, 16.848, 35.83, 21.585], [35.83, 37.95, 32.83, 32.83, 32.83, 32.83, 32.83, 32.83, 32.83, 32.83, 32.83, 26.185000000000002], [0.5165, 2.075, 1.3057], [21.585, 21.805, 16.848, 21.585, 17.1], [32.83], [1.6840000000000002, 3.4475000000000002, 3.4475000000000002, 0.00585, 0.00585, 4.388, 1.3057, 1.6840000000000002, 4.388, 3.1, 2.075, 0.00585, 1.3057, 1.3057, 0.00585, 1.3057, 1.294, 1.294, 1.294, 1.3057, 0.4022, 0.4022, 1.6840000000000002, 3.1, 3.4475000000000002, 2.075, 2.075, 1.3057, 1.3057, 2.6782, 5.2545, 1.3057, 1.3057, 1.294, 1.3057, 1.294
# ...

# %%
for key is species_ranges.keys():
    ages = species_ranges[key]
    minage = min(ages)
    maxage = max(ages)
    genus = key.split (" ")[0]
    #print (genus, key, minage, maxage)
    outline =
